# %% [markdown]
# # Lab4.06_lab-random-variable-distributions

# %% [markdown]
# ## 1.Get the numerical variables from our dataset.

# %%
# 1.Import the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from sklearn.preprocessing import StandardScaler
import datetime

# %%
from sklearn.model_selection import train_test_split

# %%
# 2.Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.
customer_df = pd.read_csv('files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
# 3.Rename the columns so they follow the PE8 (snake case)
cols = [i.lower() for i in customer_df.columns]
customer_df.columns = cols 
cols = [i.replace(' ','_') for i in customer_df.columns]
customer_df.columns = cols

# %%
# 4.Load the continuous and discrete variables into continuous_df and discrete_df variables.
customer_df_cat = customer_df.select_dtypes(object)
customer_df_num = customer_df.select_dtypes(np.number)

for i in customer_df_num.columns:
    if customer_df_num[i].nunique() > 100:
        cont.append(i)
    else:
        dis.append(i)

# %%
#Droppping custumer ID because it does not give useful information, actually is like and index
customer_df = customer_df.drop(['customer'],axis=1)

# %%
#Dividing the variables.
customer_df_num = customer_df.select_dtypes(np.number)
customer_df_num.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %% [markdown]
# ## 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
for i in customer_df_num.columns:
    sns.displot(customer_df_num[i])
    plt.show()

# %%
# customer_lifetime_value looks poisson distribution
# income looks poisson distribution
# monthly_premium_auto looks poisson distribution
# months_since_last_claim looks poisson distribution
# months_since_policy_inception
# number_of_open_complaints looks poisson distribution
# number_of_policies looks poisson distribution
# total_claim_amount looks poisson distribution

# As some os them has lots of data, i´ll try to plot them again aplying log distribution,customer_lifetime_value  
# income, total_claim_amount,monthly_premium_auto, total_claim_amount
# are the columns with continuous data.

# %% [markdown]
# ## 3.Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
continuous = customer_df_num[['customer_lifetime_value', 'total_claim_amount', 'monthly_premium_auto']]

# %%
for i in continuous.columns:
    sns.displot(continuous[i],log_scale=True)
    plt.show()

# %%
# Applyin log transformation we can see that customer_lifetime_value and total_claim_amount follows normal 
# distrinbution, but monthly_premium_auto actually has shape of poisson distribution
